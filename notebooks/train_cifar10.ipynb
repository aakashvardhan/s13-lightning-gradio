# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
repo_url = 'https://github.com/aakashvardhan/s13-lightning-gradio.git'
local_dir = 's13-lightning-gradio'

# Check if the local directory already exists
if not os.path.exists(local_dir):
    # Clone the repository because it does not exist
    # !git clone --recurse-submodules --quiet {repo_url}
else:
    # Change directory to the local repository
    # %cd {local_dir}
    # Pull the latest changes because the repository already exists
    # !git pull

# %%
import sys
sys.path.append('/content/s13-lightning-gradio/s11_gradcam')
sys.path.append('/content/s13-lightning-gradio')

# %%
# !pip install -q -r /content/s13-lightning-gradio/requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 17.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.2/802.2 kB 32.3 MB/s eta 0:00:00
#   Building wheel for grad-cam (pyproject.toml) ... done

# %%
from main import main
from config import get_config

config = get_config()

main(config,False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-53ab8ac26d90> in <cell line: 6>()
#       4 config = get_config()
#       5
# ----> 6 main(config,False)
#
# TypeError: main() missing 1 required positional argument: 'trainer'

# %%
# start tensorboard
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs/
